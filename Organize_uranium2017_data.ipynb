# %%
# Import Dependencies
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame for Poverty Rate Data
csv_path = "CountyPovertyRate.csv"
county_pov_df = pd.read_csv(csv_path)

county_pov_df.head()
# Out:
#   Rank             County Poverty Rate Urban/Rural/Sub
# 0  1st      Carver County        4.00%        Suburban
# 1  2nd  Washington County        5.00%        Suburban
# 2  3rd      Wright County        5.00%        Suburban
# 3  4th     Chisago County        5.40%           Rural
# 4  5th       Scott County        5.60%        Suburban

# %%
#Create path to csv for uranium 2017 data and read into Pandas Dataframe
csv_path = "uranium_2017.csv"
uranium2017_df= pd.read_csv(csv_path)

uranium2017_df.head()
# Out:
#      pwsId    year analyteCode                               pwsName  \
# 0  1020034  2017.0     Uranium                               Andover
# 1  1020001  2017.0     Uranium                                 Anoka
# 2  1020011  2017.0     Uranium  Village Green North Mobile Home Park
# 3  1020017  2017.0     Uranium                           Coon Rapids
# 4  1020042  2017.0     Uranium                           East Bethel
#
#   countyServed   cityServed  waterSource             mean              max  \
# 0        Anoka      Andover  Groundwater  0.33 pCi/L (ND)  0.33 pCi/L (ND)
# 1        Anoka        Anoka  Groundwater  0.34 pCi/L (ND)  0.34 pCi/L (ND)
# 2        Anoka        Cedar  Groundwater       0.19 pCi/L       0.19 pCi/L
# 3        Anoka  Coon Rapids  Groundwater  0.33 pCi/L (ND)  0.33 pCi/L (ND)
# 4        Anoka  East Bethel  Groundwater       0.73 pCi/L       0.97 pCi/L
#
#    populationServed     fips  Unnamed: 11
# 0           19918.0  27003.0          NaN
# 1           17995.0  27003.0          NaN
# 2             450.0  27003.0          NaN
# 3           61481.0  27003.0          NaN
# 4             137.0  27003.0          NaN

# %%
#verify data types in pandas database for uranium
uranium2017_df.dtypes
# Out:
# pwsId                object
# year                float64
# analyteCode          object
# pwsName              object
# countyServed         object
# cityServed           object
# waterSource          object
# mean                 object
# max                  object
# populationServed    float64
# fips                float64
# Unnamed: 11         float64
# dtype: object

# %%
#delete the empty column on the end named "Unnamed:11"
uranium2017_df=uranium2017_df.drop(columns=['Unnamed: 11'])
uranium2017_df.head()
# Out:
#      pwsId    year analyteCode                               pwsName  \
# 0  1020034  2017.0     Uranium                               Andover
# 1  1020001  2017.0     Uranium                                 Anoka
# 2  1020011  2017.0     Uranium  Village Green North Mobile Home Park
# 3  1020017  2017.0     Uranium                           Coon Rapids
# 4  1020042  2017.0     Uranium                           East Bethel
#
#   countyServed   cityServed  waterSource             mean              max  \
# 0        Anoka      Andover  Groundwater  0.33 pCi/L (ND)  0.33 pCi/L (ND)
# 1        Anoka        Anoka  Groundwater  0.34 pCi/L (ND)  0.34 pCi/L (ND)
# 2        Anoka        Cedar  Groundwater       0.19 pCi/L       0.19 pCi/L
# 3        Anoka  Coon Rapids  Groundwater  0.33 pCi/L (ND)  0.33 pCi/L (ND)
# 4        Anoka  East Bethel  Groundwater       0.73 pCi/L       0.97 pCi/L
#
#    populationServed     fips
# 0           19918.0  27003.0
# 1           17995.0  27003.0
# 2             450.0  27003.0
# 3           61481.0  27003.0
# 4             137.0  27003.0

# %%
#verify any empty data cells
uranium2017_df['mean'].isnull().sum()
# Out:
# 10

# %%
#verify what is in the empty data cells
nullData=uranium2017_df.loc[uranium2017_df['mean'].isnull()]
nullData
# Out:
#                                                  pwsId  year analyteCode  \
# 138                                            Source:   NaN         NaN
# 139                Minnesota Public Health Data Access   NaN         NaN
# 140  Minnesota Environmental Public Health Tracking...   NaN         NaN
# 141                     Minnesota Department of Health   NaN         NaN
# 142                                     P.O. Box 64882   NaN         NaN
# 143                            St. Paul, MN 55164-0882   NaN         NaN
# 144  Phone: (651) 201-5900 or toll free: 1-800-205-...   NaN         NaN
# 145                                Fax: (651) 201-5926   NaN         NaN
# 146                E-mail: tracking.health@state.mn.us   NaN         NaN
# 147                  Web: http://health.mn.gov/mndata    NaN         NaN
#
#     pwsName countyServed cityServed waterSource mean  max  populationServed  \
# 138     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 139     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 140     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 141     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 142     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 143     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 144     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 145     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 146     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 147     NaN          NaN        NaN         NaN  NaN  NaN               NaN
#
#      fips
# 138   NaN
# 139   NaN
# 140   NaN
# 141   NaN
# 142   NaN
# 143   NaN
# 144   NaN
# 145   NaN
# 146   NaN
# 147   NaN

# %%
#delete the null data and confirm no more NaN
uranium2017_df=uranium2017_df.dropna()
uranium2017_df['mean'].isnull().sum()
# Out:
# 0

# %%
#drop concentration string out of contaminate level columns "mean" and "max"
uranium2017_df['mean']=uranium2017_df['mean'].str.split(" ").str[0]
uranium2017_df['max']=uranium2017_df['max'].str.split(" ").str[0]
uranium2017_df.head()
# Out:
#      pwsId    year analyteCode                               pwsName  \
# 0  1020034  2017.0     Uranium                               Andover
# 1  1020001  2017.0     Uranium                                 Anoka
# 2  1020011  2017.0     Uranium  Village Green North Mobile Home Park
# 3  1020017  2017.0     Uranium                           Coon Rapids
# 4  1020042  2017.0     Uranium                           East Bethel
#
#   countyServed   cityServed  waterSource  mean   max  populationServed  \
# 0        Anoka      Andover  Groundwater  0.33  0.33           19918.0
# 1        Anoka        Anoka  Groundwater  0.34  0.34           17995.0
# 2        Anoka        Cedar  Groundwater  0.19  0.19             450.0
# 3        Anoka  Coon Rapids  Groundwater  0.33  0.33           61481.0
# 4        Anoka  East Bethel  Groundwater  0.73  0.97             137.0
#
#       fips
# 0  27003.0
# 1  27003.0
# 2  27003.0
# 3  27003.0
# 4  27003.0

# %%
#rename column headers for contaminates to include concentrations so the information isn't lost
uranium2017_df=uranium2017_df.rename(columns={"mean":"Mean pCi/L (ND)", "max":"Max pCi/L (ND)"})
uranium2017_df.head()
# Out:
#      pwsId    year analyteCode                               pwsName  \
# 0  1020034  2017.0     Uranium                               Andover
# 1  1020001  2017.0     Uranium                                 Anoka
# 2  1020011  2017.0     Uranium  Village Green North Mobile Home Park
# 3  1020017  2017.0     Uranium                           Coon Rapids
# 4  1020042  2017.0     Uranium                           East Bethel
#
#   countyServed   cityServed  waterSource Mean pCi/L (ND) Max pCi/L (ND)  \
# 0        Anoka      Andover  Groundwater            0.33           0.33
# 1        Anoka        Anoka  Groundwater            0.34           0.34
# 2        Anoka        Cedar  Groundwater            0.19           0.19
# 3        Anoka  Coon Rapids  Groundwater            0.33           0.33
# 4        Anoka  East Bethel  Groundwater            0.73           0.97
#
#    populationServed     fips
# 0           19918.0  27003.0
# 1           17995.0  27003.0
# 2             450.0  27003.0
# 3           61481.0  27003.0
# 4             137.0  27003.0

# %%
#convert contaminate columns from object to integer, confirm data type in columns
uranium2017_df["Mean pCi/L (ND)"] = pd.to_numeric(uranium2017_df["Mean pCi/L (ND)"])
uranium2017_df["Max pCi/L (ND)"] = pd.to_numeric(uranium2017_df["Max pCi/L (ND)"])
print(uranium2017_df.dtypes)
# Out:
# pwsId                object
# year                float64
# analyteCode          object
# pwsName              object
# countyServed         object
# cityServed           object
# waterSource          object
# Mean pCi/L (ND)     float64
# Max pCi/L (ND)      float64
# populationServed    float64
# fips                float64
# dtype: object

# %%
# Perform the ANOVA
stats.f_oneway(group1, group2, group3, group4, group5)

# %%
group1 = county_combined[county_combined[“Bin Poverty Rate”] == “1"][“Mean (ug/L)“]
group2 = county_combined[county_combined[“Bin Poverty Rate”] == “2"][“Mean (ug/L)“]
group3 = county_combined[county_combined[“Bin Poverty Rate”] == “3"][“Mean (ug/L)“]
group4 = county_combined[county_combined[“Bin Poverty Rate”] == “4"][“Mean (ug/L)“]
group5 = county_combined[county_combined[“Bin Poverty Rate”] == “5"][“Mean (ug/L)“]

# %%
#ANOVA test
stats.ttest_ind(group1, group5, equal_var=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-05b28b61f5ef> in <module>
#       1 #ANOVA test
# ----> 2 stats.ttest_ind(group1, group5, equal_var=False)
#
# NameError: name 'stats' is not defined
