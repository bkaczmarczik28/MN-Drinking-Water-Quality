# %%
import pandas as pd
import numpy as np

# %%
nitrate_df = pd.read_csv("nitrate_2017.csv")
nitrate_df.tail(50)
# Out:
#                                                  pwsId    year analyteCode  \
# 923                                            1850001  2017.0     Nitrate
# 924                                            1850003  2017.0     Nitrate
# 925                                            1850018  2017.0     Nitrate
# 926                                            1850012  2017.0     Nitrate
# 927                                            1850006  2017.0     Nitrate
# 928                                            1850017  2017.0     Nitrate
# 929                                            1850008  2017.0     Nitrate
# 930                                            1850009  2017.0     Nitrate
# 931                                            1850020  2017.0     Nitrate
# 932                                            1850011  2017.0     Nitrate
# 933                                            1850005  2017.0     Nitrate
# ...

# %%
clean_nitrate_df = nitrate_df.loc[:, ["analyteCode", "countyServed", "waterSource", "mean", "max", "populationServed"]]

# %%
clean_nitrate_df
print(clean_nitrate_df.dtypes)
# Out:
# object

# %%
clean_nitrate_df = clean_nitrate_df['mean']
clean_nitrate_df
# Out:
# 0      0.025 mg/L (ND)
# 1      0.025 mg/L (ND)
# 2      0.025 mg/L (ND)
# 3      0.025 mg/L (ND)
# 4      0.025 mg/L (ND)
#             ...
# 958    0.025 mg/L (ND)
# 959         4.812 mg/L
# 960         4.812 mg/L
# 961         4.812 mg/L
# 962    0.025 mg/L (ND)
# Name: mean, Length: 963, dtype: object

# %%
#clean_nitrate_df['mean'] = pd.to_numeric(clean_nitrate_df['mean']) 

clean_nitrate_df['mean'].replace(regex=True, inplace=True, to_replace=r'[^0-9.\-]', value=r'') clean_nitrate_df['mean'] = df['mean'].astype(float64)
clean_nitrate_df['mean']
# Out:
#   File "<ipython-input-45-1cf61f3757b1>", line 3
#     clean_nitrate_df['mean'].replace(regex=True, inplace=True, to_replace=r'[^0-9.\-]', value=r'') clean_nitrate_df['mean'] = df['mean'].astype(float64)
#                                                                                                                   ^
# SyntaxError: invalid syntax

# %%
clean_nitrate_df['mean'] = clean_nitrate_df['mean'].apply(pd.to_numeric)
clean_nitrate_df['mean']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 958   NaN
# 959   NaN
# 960   NaN
# 961   NaN
# 962   NaN
# Name: mean, Length: 963, dtype: float64
