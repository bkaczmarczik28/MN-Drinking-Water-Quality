# %%
import pandas as pd
import numpy as np

# %%
nitrate_df = pd.read_csv("nitrate_2017.csv")
nitrate_df
# Out:
#        pwsId  year analyteCode                    pwsName     countyServed  \
# 0    1010001  2017     Nitrate                     Aitkin           Aitkin
# 1    1010002  2017     Nitrate  Thompson Mobile Home Park           Aitkin
# 2    1010019  2017     Nitrate               Why-Not Park           Aitkin
# 3    1010011  2017     Nitrate                  Hill City           Aitkin
# 4    1010016  2017     Nitrate                   McGregor           Aitkin
# ..       ...   ...         ...                        ...              ...
# 958  1870005  2017     Nitrate               Hanley Falls  Yellow Medicine
# 959  1870011  2017     Nitrate                  Hazel Run  Yellow Medicine
# 960  1870006  2017     Nitrate                     Porter  Yellow Medicine
# 961  1870007  2017     Nitrate                  Saint Leo  Yellow Medicine
# 962  1870008  2017     Nitrate                  Wood Lake  Yellow Medicine
#
# ...

# %%
clean_nitrate_df = nitrate_df.loc[:, ["analyteCode", "countyServed", "waterSource", "mean", "max", "populationServed"]]

# %%
clean_nitrate_df
# Out:
#     analyteCode     countyServed            waterSource             mean  \
# 0       Nitrate           Aitkin            Groundwater  0.025 mg/L (ND)
# 1       Nitrate           Aitkin            Groundwater  0.025 mg/L (ND)
# 2       Nitrate           Aitkin            Groundwater  0.025 mg/L (ND)
# 3       Nitrate           Aitkin            Groundwater  0.025 mg/L (ND)
# 4       Nitrate           Aitkin            Groundwater  0.025 mg/L (ND)
# ..          ...              ...                    ...              ...
# 958     Nitrate  Yellow Medicine            Groundwater  0.025 mg/L (ND)
# 959     Nitrate  Yellow Medicine  Purchased Groundwater       4.812 mg/L
# 960     Nitrate  Yellow Medicine  Purchased Groundwater       4.812 mg/L
# 961     Nitrate  Yellow Medicine  Purchased Groundwater       4.812 mg/L
# 962     Nitrate  Yellow Medicine            Groundwater  0.025 mg/L (ND)
#
#                  max  populationServed
# 0    0.025 mg/L (ND)              2165
# ...
