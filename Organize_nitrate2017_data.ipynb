# %%
# Import Dependencies
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame for Poverty Rate Data
csv_path = "CountyPovertyRate.csv"
county_pov_df = pd.read_csv(csv_path)

county_pov_df.head()
# Out:
#   Rank             County Poverty Rate Urban/Rural/Sub
# 0  1st      Carver County        4.00%        Suburban
# 1  2nd  Washington County        5.00%        Suburban
# 2  3rd      Wright County        5.00%        Suburban
# 3  4th     Chisago County        5.40%           Rural
# 4  5th       Scott County        5.60%        Suburban

# %%
#Create path to csv for nitrate 2017 data and read into Pandas Dataframe
csv_path = "nitrate_2017.csv"
nitrate2017_df= pd.read_csv(csv_path)

nitrate2017_df.head()
# Out:
#      pwsId    year analyteCode                    pwsName countyServed  \
# 0  1010001  2017.0     Nitrate                     Aitkin       Aitkin
# 1  1010002  2017.0     Nitrate  Thompson Mobile Home Park       Aitkin
# 2  1010019  2017.0     Nitrate               Why-Not Park       Aitkin
# 3  1010011  2017.0     Nitrate                  Hill City       Aitkin
# 4  1010016  2017.0     Nitrate                   McGregor       Aitkin
#
#   cityServed  waterSource             mean              max  populationServed  \
# 0     Aitkin  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)            2165.0
# 1     Aitkin  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)              45.0
# 2     Aitkin  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)              25.0
# 3  Hill City  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)             633.0
# 4   McGregor  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)             394.0
#
#       fips  Unnamed: 11
# 0  27001.0          NaN
# 1  27001.0          NaN
# 2  27001.0          NaN
# 3  27001.0          NaN
# 4  27001.0          NaN

# %%
#verify data types in pandas database for Nitrate
nitrate2017_df.dtypes
# Out:
# pwsId                object
# year                float64
# analyteCode          object
# pwsName              object
# countyServed         object
# cityServed           object
# waterSource          object
# mean                 object
# max                  object
# populationServed    float64
# fips                float64
# Unnamed: 11         float64
# dtype: object

# %%
#delete the empty column on the end named "Unnamed:11"
nitrate2017_df=nitrate2017_df.drop(columns=['Unnamed: 11'])
nitrate2017_df.head()
# Out:
#      pwsId    year analyteCode                    pwsName countyServed  \
# 0  1010001  2017.0     Nitrate                     Aitkin       Aitkin
# 1  1010002  2017.0     Nitrate  Thompson Mobile Home Park       Aitkin
# 2  1010019  2017.0     Nitrate               Why-Not Park       Aitkin
# 3  1010011  2017.0     Nitrate                  Hill City       Aitkin
# 4  1010016  2017.0     Nitrate                   McGregor       Aitkin
#
#   cityServed  waterSource             mean              max  populationServed  \
# 0     Aitkin  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)            2165.0
# 1     Aitkin  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)              45.0
# 2     Aitkin  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)              25.0
# 3  Hill City  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)             633.0
# 4   McGregor  Groundwater  0.025 mg/L (ND)  0.025 mg/L (ND)             394.0
#
#       fips
# 0  27001.0
# 1  27001.0
# 2  27001.0
# 3  27001.0
# 4  27001.0

# %%
#verify any empty data cells
nitrate2017_df['mean'].isnull().sum()
# Out:
# 10

# %%
#verify what is in the empty data cells
nullData=nitrate2017_df.loc[nitrate2017_df['mean'].isnull()]
nullData
# Out:
#                                                  pwsId  year analyteCode  \
# 963                                            Source:   NaN         NaN
# 964                Minnesota Public Health Data Access   NaN         NaN
# 965  Minnesota Environmental Public Health Tracking...   NaN         NaN
# 966                     Minnesota Department of Health   NaN         NaN
# 967                                     P.O. Box 64882   NaN         NaN
# 968                            St. Paul, MN 55164-0882   NaN         NaN
# 969  Phone: (651) 201-5900 or toll free: 1-800-205-...   NaN         NaN
# 970                                Fax: (651) 201-5926   NaN         NaN
# 971                E-mail: tracking.health@state.mn.us   NaN         NaN
# 972                  Web: http://health.mn.gov/mndata    NaN         NaN
#
#     pwsName countyServed cityServed waterSource mean  max  populationServed  \
# 963     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 964     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 965     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 966     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 967     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 968     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 969     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 970     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 971     NaN          NaN        NaN         NaN  NaN  NaN               NaN
# 972     NaN          NaN        NaN         NaN  NaN  NaN               NaN
#
#      fips
# 963   NaN
# 964   NaN
# 965   NaN
# 966   NaN
# 967   NaN
# 968   NaN
# 969   NaN
# 970   NaN
# 971   NaN
# 972   NaN

# %%
#delete the null data and confirm no more NaN
nitrate2017_df=nitrate2017_df.dropna()
nitrate2017_df['mean'].isnull().sum()
# Out:
# 0

# %%
#drop concentration string out of contaminate level columns "mean" and "max"
nitrate2017_df['mean']=nitrate2017_df['mean'].str.split(" ").str[0]
nitrate2017_df['max']=nitrate2017_df['max'].str.split(" ").str[0]
nitrate2017_df.head()
# Out:
#      pwsId    year analyteCode                    pwsName countyServed  \
# 0  1010001  2017.0     Nitrate                     Aitkin       Aitkin
# 1  1010002  2017.0     Nitrate  Thompson Mobile Home Park       Aitkin
# 2  1010019  2017.0     Nitrate               Why-Not Park       Aitkin
# 3  1010011  2017.0     Nitrate                  Hill City       Aitkin
# 4  1010016  2017.0     Nitrate                   McGregor       Aitkin
#
#   cityServed  waterSource   mean    max  populationServed     fips
# 0     Aitkin  Groundwater  0.025  0.025            2165.0  27001.0
# 1     Aitkin  Groundwater  0.025  0.025              45.0  27001.0
# 2     Aitkin  Groundwater  0.025  0.025              25.0  27001.0
# 3  Hill City  Groundwater  0.025  0.025             633.0  27001.0
# 4   McGregor  Groundwater  0.025  0.025             394.0  27001.0

# %%
#rename column headers for contaminates to include concentrations so the information isn't lost
nitrate2017_df=nitrate2017_df.rename(columns={"mean":"Mean mg/L (ND)", "max":"Max mg/L (ND)"})
nitrate2017_df.head()
# Out:
#      pwsId    year analyteCode                    pwsName countyServed  \
# 0  1010001  2017.0     Nitrate                     Aitkin       Aitkin
# 1  1010002  2017.0     Nitrate  Thompson Mobile Home Park       Aitkin
# 2  1010019  2017.0     Nitrate               Why-Not Park       Aitkin
# 3  1010011  2017.0     Nitrate                  Hill City       Aitkin
# 4  1010016  2017.0     Nitrate                   McGregor       Aitkin
#
#   cityServed  waterSource Mean mg/L (ND) Max mg/L (ND)  populationServed  \
# 0     Aitkin  Groundwater          0.025         0.025            2165.0
# 1     Aitkin  Groundwater          0.025         0.025              45.0
# 2     Aitkin  Groundwater          0.025         0.025              25.0
# 3  Hill City  Groundwater          0.025         0.025             633.0
# 4   McGregor  Groundwater          0.025         0.025             394.0
#
#       fips
# 0  27001.0
# 1  27001.0
# 2  27001.0
# 3  27001.0
# 4  27001.0

# %%
#convert contaminate columns from object to integer, confirm data type in columns
nitrate2017_df["Mean mg/L (ND)"] = pd.to_numeric(nitrate2017_df["Mean mg/L (ND)"])
nitrate2017_df["Max mg/L (ND)"] = pd.to_numeric(nitrate2017_df["Max mg/L (ND)"])
print(nitrate2017_df.dtypes)
# Out:
# pwsId                object
# year                float64
# analyteCode          object
# pwsName              object
# countyServed         object
# cityServed           object
# waterSource          object
# Mean mg/L (ND)      float64
# Max mg/L (ND)       float64
# populationServed    float64
# fips                float64
# dtype: object
